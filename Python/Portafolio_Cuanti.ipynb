# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
Presion_Extrusion = [8500, 8700, 8900, 9100]
Lotes_Resina = [1, 2, 3, 4, 5, 6]
Rendimiento = [[90.3, 92.5, 85.5, 82.5],
               [89.2, 89.5, 90.8, 89.5],
               [98.2, 90.6, 89.6, 85.6],
               [93.9, 94.7, 86.2, 87.4],
               [87.4, 87, 88, 78.9],
               [97, 95.8, 93.4, 90.7]]

# %%
df = pd.DataFrame({
    'presion_extrusion': Presion_Extrusion * 6,
    'Lote_resina': [i for i in Lotes_Resina for _ in range(4)],
    'Rendimiento': [j for sublist in Rendimiento for j in sublist]
})
df.head()
# Out:
#    presion_extrusion  Lote_resina  Rendimiento
# 0               8500            1         90.3
# 1               8700            1         92.5
# 2               8900            1         85.5
# 3               9100            1         82.5
# 4               8500            2         89.2

# %%
model = ols('Rendimiento ~ C(presion_extrusion) + C(Lote_resina)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ = 2)
print(anova_table)
# Out:
#                           sum_sq    df         F    PR(>F)
# C(presion_extrusion)  172.835000   3.0  7.883370  0.002171
# C(Lote_resina)        184.043333   5.0  5.036763  0.006599
# Residual              109.620000  15.0       NaN       NaN

# %%
# !pip install bioinfokit
# Out:
# ^C
# Collecting bioinfokit
#   Downloading bioinfokit-2.1.3.tar.gz (87 kB)
#      ---------------------------------------- 0.0/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.7 kB ? eta -:--:--
#      --------------------------------------- 87.7/87.7 kB 17.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (2.0.3)
# Requirement already satisfied: numpy in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (3.7.2)
# Requirement already satisfied: scipy in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (1.11.2)
# Requirement already satisfied: scikit-learn in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (1.3.0)
# Requirement already satisfied: seaborn in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (0.12.2)
# Collecting matplotlib-venn (from bioinfokit)
#   Downloading matplotlib-venn-0.11.9.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tabulate (from bioinfokit)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: statsmodels in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from bioinfokit) (0.14.0)
# Collecting textwrap3 (from bioinfokit)
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Collecting adjustText (from bioinfokit)
#   Downloading adjustText-0.8-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\16joa\appdata\roaming\python\python311\site-packages (from matplotlib->bioinfokit) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->bioinfokit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\16joa\appdata\roaming\python\python311\site-packages (from matplotlib->bioinfokit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from pandas->bioinfokit) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from pandas->bioinfokit) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->bioinfokit) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->bioinfokit) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\16joa\appdata\local\programs\python\python311\lib\site-packages (from statsmodels->bioinfokit) (0.5.3)
# Requirement already satisfied: six in c:\users\16joa\appdata\roaming\python\python311\site-packages (from patsy>=0.5.2->statsmodels->bioinfokit) (1.16.0)
# Building wheels for collected packages: bioinfokit, matplotlib-venn
#   Building wheel for bioinfokit (setup.py): started
#   Building wheel for bioinfokit (setup.py): finished with status 'done'
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.3-py3-none-any.whl size=59176 sha256=de07400d3acff5ad0dde334771d467c9d88209cb906ef614aa6e6885b284d271
#   Stored in directory: c:\users\16joa\appdata\local\pip\cache\wheels\17\b1\27\a08cd47cae31d28f2dd8951e3e2fe78e9ce3f8ee93afe01906
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-0.11.9-py3-none-any.whl size=33037 sha256=8d3a5744eb5393b5a64ac1504e11252ce9a85dbbccb9156ef2256973605f5c84
#   Stored in directory: c:\users\16joa\appdata\local\pip\cache\wheels\f6\80\48\193eff32ed8e176623b15874055438ecec522ba68ed05abee6
# Successfully built bioinfokit matplotlib-venn
# Installing collected packages: textwrap3, tabulate, matplotlib-venn, adjustText, bioinfokit
# Successfully installed adjustText-0.8 bioinfokit-2.1.3 matplotlib-venn-0.11.9 tabulate-0.9.0 textwrap3-0.9.2

# %%
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=df, res_var='Rendimiento', anova_model='Rendimiento~C(presion_extrusion)+C(Lote_resina)')
res.anova_summary
# Out:
#                         df      sum_sq    mean_sq         F    PR(>F)
# C(presion_extrusion)   3.0  172.835000  57.611667  7.883370  0.002171
# C(Lote_resina)         5.0  184.043333  36.808667  5.036763  0.006599
# Residual              15.0  109.620000   7.308000       NaN       NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['df'].plot(kind='hist', bins=20, title='df')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sum_sq'].plot(kind='hist', bins=20, title='sum_sq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['mean_sq'].plot(kind='hist', bins=20, title='mean_sq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['F'].plot(kind='hist', bins=20, title='F')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='df', y='sum_sq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='sum_sq', y='mean_sq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='mean_sq', y='F', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='F', y='PR(>F)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['df']
#   ys = series['sum_sq']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('df', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('df')
# _ = plt.ylabel('sum_sq')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['df']
#   ys = series['mean_sq']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('df', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('df')
# _ = plt.ylabel('mean_sq')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['df']
#   ys = series['F']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('df', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('df')
# _ = plt.ylabel('F')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['df']
#   ys = series['PR(>F)']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('df', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('df')
# _ = plt.ylabel('PR(>F)')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['df'].plot(kind='line', figsize=(8, 4), title='df')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['sum_sq'].plot(kind='line', figsize=(8, 4), title='sum_sq')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['mean_sq'].plot(kind='line', figsize=(8, 4), title='mean_sq')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['F'].plot(kind='line', figsize=(8, 4), title='F')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
def validar_precio():
    while True:
        try:
            precio = float(input("Ingrese el precio del certificado (entre 0 y 50000): "))
            if 0 <= precio <= 50000:
                return precio
            else:
                print("El precio debe estar entre 0 y 50000.")
        except ValueError:
            print("Por favor, ingrese un número válido.")

def validar_tipo_tramite():
    while True:
        try:
            tipo_tramite = int(input("Ingrese el tipo de trámite (1 - presencial, 2 - online): "))
            if tipo_tramite in [1, 2]:
                return tipo_tramite
            else:
                print("El tipo de trámite debe ser 1 (presencial) o 2 (online).")
        except ValueError:
            print("Por favor, ingrese 1 o 2 para el tipo de trámite.")

def validar_especificacion():
    while True:
        try:
            especificacion = int(input("Ingrese la especificación del certificado (1 - nacimiento, 2 - defunción, 3 - matrimonio): "))
            if especificacion in [1, 2, 3]:
                return especificacion
            else:
                print("La especificación debe ser 1 (nacimiento), 2 (defunción) o 3 (matrimonio).")
        except ValueError:
            print("Por favor, ingrese 1, 2 o 3 para la especificación.")

n = int(input("Ingrese el número de solicitudes de certificado: "))

for i in range(1, n + 1):
    print(f"Vuelta {i} del ciclo:")
    precio = validar_precio()
    tipo_tramite = validar_tipo_tramite()
    especificacion = validar_especificacion()

    print(f"Solicitud {i}: Precio: {precio}, Tipo de Trámite: {tipo_tramite}, Especificación: {especificacion}")

print("Proceso completado.")
# Out:
# Ingrese el número de solicitudes de certificado: 2
# Vuelta 1 del ciclo:
# Ingrese el precio del certificado (entre 0 y 50000): 35000
# Ingrese el tipo de trámite (1 - presencial, 2 - online): 2
# Ingrese la especificación del certificado (1 - nacimiento, 2 - defunción, 3 - matrimonio): 3
# Solicitud 1: Precio: 35000.0, Tipo de Trámite: 2, Especificación: 3
# Vuelta 2 del ciclo:
# Ingrese el precio del certificado (entre 0 y 50000): 10000
# Ingrese el tipo de trámite (1 - presencial, 2 - online): 1
# Ingrese la especificación del certificado (1 - nacimiento, 2 - defunción, 3 - matrimonio): 1
# Solicitud 2: Precio: 10000.0, Tipo de Trámite: 1, Especificación: 1
# Proceso completado.

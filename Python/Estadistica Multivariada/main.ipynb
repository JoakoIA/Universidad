# %% [markdown]
# # Item 1

# %% [markdown]
# ### Repaso
# Covarianza:
# La covarianza es una medida estadística que describe la relación entre dos variables aleatorias. Indica si las dos variables tienden a aumentar o disminuir juntas. Es una medida de la tendencia conjunta de dos variables a variar al mismo tiempo. La covarianza se calcula como la media del producto de las desviaciones de cada variable respecto a sus medias respectivas. Si la covarianza es positiva, significa que cuando una variable es mayor que su media, la otra también tiende a ser mayor que su media, y viceversa. Si es negativa, indica que cuando una variable es mayor que su media, la otra tiende a ser menor que su media.
#
# Covarianza Semidefinida Positiva:
# La covarianza semidefinida positiva se refiere a las propiedades de una matriz de covarianza. Una matriz es semidefinida positiva si satisface dos condiciones:
#
#     Todos sus valores propios (eigenvalues) son no negativos o mayores que cero.
#     La matriz es simétrica.
#
# En el contexto de la matriz de covarianza, esto significa que la matriz de covarianza es semidefinida positiva si todas sus variables están correlacionadas de una manera no negativa o positiva. Si todas las covarianzas entre las variables son no negativas, entonces la matriz de covarianza será semidefinida positiva.
#
# Covarianza:
# $\text{cov}(X, Y) = \frac{1}{N} \sum_{i=1}^{N} (X_i - \bar{X})(Y_i - \bar{Y})$
#
#
# Eigenvalues:
# $\det(A - \lambda I) = 0$

# %% [markdown]
# # Item 2

# %%
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Matriz de 6x3
matrix = np.matrix([[-2,1,4],[3,0,-1],[5,1,2],[-1,3,6],[2,-7,4],[-1,0,-1]])
print(matrix)
# Out:
# [[-2  1  4]
#  [ 3  0 -1]
#  [ 5  1  2]
#  [-1  3  6]
#  [ 2 -7  4]
#  [-1  0 -1]]

# %%
#Calcule el vector de medias, la matriz de covarianzas y la matriz de correlaciones muestrales de x
# Calcular el vector de medias
media = np.mean(matrix, axis=0)

# Calcular la matriz de covarianzas
covarianza = np.cov(matrix, rowvar=False)

# Calcular la matriz de correlaciones
correlaciones = np.corrcoef(matrix, rowvar=False)

print("Vector de medias:")
print(media)
print("\nMatriz de covarianzas:")
print(covarianza)
print("\nMatriz de correlaciones:")
print(correlaciones)
# Out:
# Vector de medias:
# [[ 1.         -0.33333333  2.33333333]]
#
# Matriz de covarianzas:
# [[ 7.6        -2.4        -2.4       ]
#  [-2.4        11.86666667  0.13333333]
#  [-2.4         0.13333333  8.26666667]]
#
# Matriz de correlaciones:
# [[ 1.         -0.25272027 -0.3027884 ]
#  [-0.25272027  1.          0.01346199]
#  [-0.3027884   0.01346199  1.        ]]

# %%
#Calcule la matriz de covarianzas de los datos estandarizados univeriados y los datosestandarizados multivariados (2 pts)
# Datos estandarizados univariados
matriz_estandarizada = (matrix - vector_medias)/np.std(matrix, axis=0)
print(matriz_estandarizada)

# Calcular la matriz de covarianzas de los datos estandarizados univariados
matriz_covarianzas_univariados = np.cov(matriz_estandarizada, rowvar=False)
print("Matriz de Covarianzas de Datos Estandarizados Univariados:")
print(matriz_covarianzas_univariados)
# Out:
# [[-1.19207912  0.42399915  0.63500064]
#  [ 0.79471941  0.10599979 -1.27000127]
#  [ 1.58943883  0.42399915 -0.12700013]
#  [-0.79471941  1.05999788  1.3970014 ]
#  [ 0.39735971 -2.11999576  0.63500064]
#  [-0.79471941  0.10599979 -1.27000127]]

# %%
# Calcular la matriz de covarianzas de los datos estandarizados univariados
matriz_covarianzas_univariados = np.cov(matriz_estandarizada, rowvar=False)
print("Matriz de Covarianzas de Datos Estandarizados Univariados:")
print(matriz_covarianzas_univariados)
# Out:
# Matriz de Covarianzas de Datos Estandarizados Univariados:
# [[ 1.2        -0.30326432 -0.36334608]
#  [-0.30326432  1.2         0.01615438]
#  [-0.36334608  0.01615438  1.2       ]]

# %%
# Calcular la matriz de covarianzas de los datos estandarizados multivariados
z_scores_multivariados = (matrix - np.mean(matrix, axis=0)) / np.std(matrix, axis=0)
matriz_covarianzas_multivariados = np.cov(matriz_estandarizada, rowvar=False)
print(matriz_covarianzas_multivariados)
# Out:
# [[ 1.2        -0.30326432 -0.36334608]
#  [-0.30326432  1.2         0.01615438]
#  [-0.36334608  0.01615438  1.2       ]]

# %%
# Out:
# Matriz de Covarianzas (Univariada):
# [[ 1.2        -0.30326432 -0.36334608]
#  [-0.30326432  1.2         0.01615438]
#  [-0.36334608  0.01615438  1.2       ]]
#
# Matriz de Covarianzas (Multivariada):
# [[ 1.00000000e+00 -2.58724107e-17 -5.87466809e-18]
#  [-2.58724107e-17  1.00000000e+00 -2.05391635e-17]
#  [-5.87466809e-18 -2.05391635e-17  1.00000000e+00]]

# %% [markdown]
# ### Leer el set de datos

# %%
df = pd.read_csv('crabs_dataset.csv')
columnas = ['FL', 'RW', 'CL', 'CW', 'BD']
data = df[columnas]

# %% [markdown]
# ### Calcular la matriz de covarianza
# Solo para las variables que nos interesa analizar

# %%
cov_matrix = np.cov(data, rowvar=False)
cov_matrix
# Out:
# array([[12.21729749,  8.15804472, 24.35667688, 26.5508005 , 11.82258141],
#        [ 8.15804472,  6.62207814, 16.35466156, 18.23963995,  7.83665905],
#        [24.35667688, 16.35466156, 50.67991935, 55.76137714, 23.9713892 ],
#        [26.5508005 , 18.23963995, 55.76137714, 61.96767814, 26.09186709],
#        [11.82258141,  7.83665905, 23.9713892 , 26.09186709, 11.72906508]])

# %%
plt.figure(figsize=(8, 6))
plt.imshow(cov_matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title("Matriz de Covarianza")
plt.xticks(range(len(columnas)), columnas)
plt.yticks(range(len(columnas)), columnas)
plt.show()

# %%
# Verificar si la matriz de covarianza es semidefinida positiva
is_semidefinite_positive = np.all(np.linalg.eigvals(cov_matrix) >= 0) #Calcular los autovalores de la matriz de covarianza

if is_semidefinite_positive:
    print("La matriz de covarianza es semidefinida positiva.")
else:
    print("La matriz de covarianza no es semidefinida positiva.")
# Out:
# La matriz de covarianza es semidefinida positiva.

# %% [markdown]
# * Repaso

# %% [markdown]
# # Item 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('crabs_dataset.csv')

# %%
data.head()
# Out:
#   sp sex  index   FL   RW    CL    CW   BD
# 0  B   M      1  8.1  6.7  16.1  19.0  7.0
# 1  B   M      2  8.8  7.7  18.1  20.8  7.4
# 2  B   M      3  9.2  7.8  19.0  22.4  7.7
# 3  B   M      4  9.6  7.9  20.1  23.1  8.2
# 4  B   M      5  9.8  8.0  20.3  23.0  8.2

# %%
# Realice el boxplot de cada medida numérica para cada especie
columnas = ['FL', 'RW', 'CL', 'CW', 'BD']

plt.figure(figsize=(8, 6))
plt.boxplot(data.values)
plt.xticks(range(1, len(columnas) + 1), columnas)
plt.title("Boxplot de cada medida numérica para cada especie")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\16joa\OneDrive\Documentos\GitHub\Universidad\Python\Calculo Multivariable\main.ipynb Celda 25 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> columnas = ['FL', 'RW', 'CL', 'CW', 'BD']
#       <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize=(8, 6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> plt.boxplot(data.values)
# ...

# %%
# Realice el boxplot de cada medida numérica para cada sexo.
columnas = ['FL', 'RW', 'CL', 'CW', 'BD']

plt.figure(figsize=(8, 6))
sns.boxplot(data.values, hue = "sex")
plt.xticks(range(1, len(columnas) + 1), columnas)
plt.title("Boxplot de cada medida numérica para cada sexo")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\16joa\OneDrive\Documentos\GitHub\Universidad\Python\Calculo Multivariable\main.ipynb Celda 26 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> columnas = ['FL', 'RW', 'CL', 'CW', 'BD']
#       <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize=(8, 6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16joa/OneDrive/Documentos/GitHub/Universidad/Python/Calculo%20Multivariable/main.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> sns.boxplot(data.values, hue = "sex")
# ...

# %%
#Calcule el vector de medias, la matriz de covarianzas y la matriz de correlaciones de las cincomedidas numéricas. Muestra la matriz de correlaciones con el heatmap
columnas = ['FL', 'RW', 'CL', 'CW', 'BD']
datas = data[columnas]

# Vector de medias
vector_medias = np.mean(datas, axis=0)
print(vector_medias)

# Matriz de covarianzas
matriz_covarianzas = np.cov(datas, rowvar=False)

# Matriz de correlaciones
matriz_corr = np.corrcoef(datas, rowvar=False)

#Graficar las matrices de correlacion
sns.heatmap(matriz_corr, cmap='viridis', annot=True, fmt='.2f', xticklabels=columnas, yticklabels=columnas)
plt.title("Matriz de Covarianzas")
plt.show()
# Out:
# FL    15.5830
# RW    12.7385
# CL    32.1055
# CW    36.4145
# BD    14.0305
# dtype: float64

# %%
#Realice scatterplot matriz de las cinco medidas numéricas con color para cada 
sns.pairplot(data, hue = "sp", vars = columnas)
plt.show
# Out:
# c:\Users\16joa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Realice scatterplot matriz de las cinco medidas numéricas con color para cada sexo

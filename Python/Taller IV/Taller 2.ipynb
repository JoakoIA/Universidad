# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Cargar el dataset
data = pd.read_csv("heart.csv")

# Mostrar las primeras filas del dataset y la información general
data_shape = data.shape
data_head = data.head()
data_info = data.info()
data_describe = data.describe()

(data_shape, data_head, data_info, data_describe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# ((303, 14),
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp
#  0   63    1   3     145   233    1        0       150     0      2.3    0  \
# ...

# %%
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  \
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  \
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True,cmap="YlGnBu")
plt.show()

# %%
#Crear un diagrama de cajas para cada variable
plt.figure(figsize=(15,10))
sns.boxplot(data=data)
plt.show()

# %%
y
# Out:
# 0        32.0
# 1        32.3
# 2        31.8
# 3        33.6
# 4        32.8
#          ...
# 53382    13.3
# 53383    25.3
# 53384    18.3
# 53385    24.1
# 53386    30.3
# Name: Data_Value, Length: 48346, dtype: float64

# %%
#Ver cuantas veces se repite cada valor unico de age
data["age"].value_counts()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
#Como convertir una variable con 2 tipos de valores a 0 y 1
#Crear histograma de cada variable
plt.figure(figsize=(15,10))
data.hist()
plt.show()

# %%
# Definir el modelo
import bambi as bnb
model = bmb.Model("charges ~ age + sex + bmi + children + smoker + region", train_data)

# Ajustar el modelo
results = model.fit(draws=1000, cores=2)

#Calcular indice waic
results.waic

#Como calculo la cantidad de combinaciones posibles de 6 variables con un maximo de 4 variables por combinacion.
